# %% [markdown]
# # Theory · Chapter 49
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch49)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [correlated_matter_companion.py](../examples/python/ch49/correlated_matter_companion.py)
# - [generate_figures.py](../examples/python/ch49/generate_figures.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch49").is_dir())
chapter_dir = theory_root / "examples/python/ch49"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'correlated_matter_companion.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
