# %% [markdown]
# # Theory · Chapter 20
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch20)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [blackbody_companion.py](../examples/python/ch20/blackbody_companion.py)
# - [generate_figures.py](../examples/python/ch20/generate_figures.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch20").is_dir())
chapter_dir = theory_root / "examples/python/ch20"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'blackbody_companion.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
