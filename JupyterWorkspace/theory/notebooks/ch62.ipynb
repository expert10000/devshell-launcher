# %% [markdown]
# # Theory · Chapter 62
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch62)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [crystalline_higher_order.py](../examples/python/ch62/crystalline_higher_order.py)
# - [disorder_real_space_topology.py](../examples/python/ch62/disorder_real_space_topology.py)
# - [generate_commit652_geometric_topology_figures.py](../examples/python/ch62/generate_commit652_geometric_topology_figures.py)
# - [generate_commit653_topological_band_figures.py](../examples/python/ch62/generate_commit653_topological_band_figures.py)
# - [generate_commit654_symmetry_topology_figures.py](../examples/python/ch62/generate_commit654_symmetry_topology_figures.py)
# - [generate_commit655_crystalline_visuals.py](../examples/python/ch62/generate_commit655_crystalline_visuals.py)
# - [generate_commit656_disorder_realspace_figures.py](../examples/python/ch62/generate_commit656_disorder_realspace_figures.py)
# - [generate_commit657_interacting_topology_visuals.py](../examples/python/ch62/generate_commit657_interacting_topology_visuals.py)
# - [generate_commit658_crystal_hamiltonian_visuals.py](../examples/python/ch62/generate_commit658_crystal_hamiltonian_visuals.py)
# - [generate_commit659_hamiltonian_atlas.py](../examples/python/ch62/generate_commit659_hamiltonian_atlas.py)
# - [generate_commit660_reference_visuals.py](../examples/python/ch62/generate_commit660_reference_visuals.py)
# - [generate_commit664_designed_hamiltonian_panels.py](../examples/python/ch62/generate_commit664_designed_hamiltonian_panels.py)
# - [generate_commit665_designed_conceptual_panels.py](../examples/python/ch62/generate_commit665_designed_conceptual_panels.py)
# - [generate_commit666_visual_qa_figures.py](../examples/python/ch62/generate_commit666_visual_qa_figures.py)
# - [generate_commit677_release_visuals.py](../examples/python/ch62/generate_commit677_release_visuals.py)
# - [geometric_topology_launch.py](../examples/python/ch62/geometric_topology_launch.py)
# - [interacting_topology.py](../examples/python/ch62/interacting_topology.py)
# - [symmetry_topology_semimetals.py](../examples/python/ch62/symmetry_topology_semimetals.py)
# - [topological_band_models.py](../examples/python/ch62/topological_band_models.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch62").is_dir())
chapter_dir = theory_root / "examples/python/ch62"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'crystalline_higher_order.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
