# %% [markdown]
# # Theory · Chapter 57
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch57)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [ch57_quantitative_prefreeze.py](../examples/python/ch57/ch57_quantitative_prefreeze.py)
# - [entanglement_frustration_lab.py](../examples/python/ch57/entanglement_frustration_lab.py)
# - [exchange_chain_lab.py](../examples/python/ch57/exchange_chain_lab.py)
# - [generate_ch57_freeze_manifest.py](../examples/python/ch57/generate_ch57_freeze_manifest.py)
# - [open_spin_dynamics.py](../examples/python/ch57/open_spin_dynamics.py)
# - [qa_ch57_commit631.py](../examples/python/ch57/qa_ch57_commit631.py)
# - [qa_commit630.py](../examples/python/ch57/qa_commit630.py)
# - [spin_dynamics_response_lab.py](../examples/python/ch57/spin_dynamics_response_lab.py)
# - [spin_exchange_lab.py](../examples/python/ch57/spin_exchange_lab.py)
# - [spin_transport_collective.py](../examples/python/ch57/spin_transport_collective.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch57").is_dir())
chapter_dir = theory_root / "examples/python/ch57"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'ch57_quantitative_prefreeze.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
