# %% [markdown]
# # Theory · Chapter 56
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch56)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [floquet_quench_wavepacket_lab.py](../examples/python/ch56/floquet_quench_wavepacket_lab.py)
# - [frequency_localization_scaling_lab.py](../examples/python/ch56/frequency_localization_scaling_lab.py)
# - [gauge_covariant_topology_lab.py](../examples/python/ch56/gauge_covariant_topology_lab.py)
# - [kubo_disorder_scattering_lab.py](../examples/python/ch56/kubo_disorder_scattering_lab.py)
# - [periodic_band_lab.py](../examples/python/ch56/periodic_band_lab.py)
# - [polarization_pump_transport_lab.py](../examples/python/ch56/polarization_pump_transport_lab.py)
# - [spin_orbit_lattice_lab.py](../examples/python/ch56/spin_orbit_lattice_lab.py)
# - [tight_binding_wannier_lab.py](../examples/python/ch56/tight_binding_wannier_lab.py)
# - [two_dimensional_sublattice_lab.py](../examples/python/ch56/two_dimensional_sublattice_lab.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch56").is_dir())
chapter_dir = theory_root / "examples/python/ch56"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'floquet_quench_wavepacket_lab.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
