# %% [markdown]
# # Theory · Chapter 55
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch55)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [molecular_hamiltonians.py](../examples/python/ch55/molecular_hamiltonians.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch55").is_dir())
chapter_dir = theory_root / "examples/python/ch55"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'molecular_hamiltonians.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
