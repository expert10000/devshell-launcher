# %% [markdown]
# # Theory · Chapter 60
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch60)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [ch60_commit640_open_foundations.py](../examples/python/ch60/ch60_commit640_open_foundations.py)
# - [ch60_commit641_lindblad.py](../examples/python/ch60/ch60_commit641_lindblad.py)
# - [ch60_commit642_trajectories_nonmarkov.py](../examples/python/ch60/ch60_commit642_trajectories_nonmarkov.py)
# - [error_channels.py](../examples/python/ch60/error_channels.py)
# - [generate_commit643_control_figures.py](../examples/python/ch60/generate_commit643_control_figures.py)
# - [generate_commit644_noise_figures.py](../examples/python/ch60/generate_commit644_noise_figures.py)
# - [open_system_control.py](../examples/python/ch60/open_system_control.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch60").is_dir())
chapter_dir = theory_root / "examples/python/ch60"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'ch60_commit640_open_foundations.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
