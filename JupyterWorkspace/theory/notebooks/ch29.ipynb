# %% [markdown]
# # Theory · Chapter 29
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch29)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [generate_figures.py](../examples/python/ch29/generate_figures.py)
# - [many_particle_companion.py](../examples/python/ch29/many_particle_companion.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch29").is_dir())
chapter_dir = theory_root / "examples/python/ch29"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'many_particle_companion.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
