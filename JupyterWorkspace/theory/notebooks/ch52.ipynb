# %% [markdown]
# # Theory · Chapter 52
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch52)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [atomic_many_electron.py](../examples/python/ch52/atomic_many_electron.py)
# - [atomic_metrology.py](../examples/python/ch52/atomic_metrology.py)
# - [atomic_radiative.py](../examples/python/ch52/atomic_radiative.py)
# - [atomic_spectroscopy.py](../examples/python/ch52/atomic_spectroscopy.py)
# - [generate_figures.py](../examples/python/ch52/generate_figures.py)
# - [generate_metrology_figures.py](../examples/python/ch52/generate_metrology_figures.py)
# - [generate_radiative_figures.py](../examples/python/ch52/generate_radiative_figures.py)
# - [generate_spectroscopy_figures.py](../examples/python/ch52/generate_spectroscopy_figures.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch52").is_dir())
chapter_dir = theory_root / "examples/python/ch52"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'atomic_many_electron.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
