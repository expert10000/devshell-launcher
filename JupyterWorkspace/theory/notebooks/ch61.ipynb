# %% [markdown]
# # Theory · Chapter 61
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch61)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [bcs_mean_field.py](../examples/python/ch61/bcs_mean_field.py)
# - [bdg_josephson.py](../examples/python/ch61/bdg_josephson.py)
# - [generate_commit645_many_body_figures.py](../examples/python/ch61/generate_commit645_many_body_figures.py)
# - [generate_commit646_bcs_figures.py](../examples/python/ch61/generate_commit646_bcs_figures.py)
# - [generate_commit647_bdg_figures.py](../examples/python/ch61/generate_commit647_bdg_figures.py)
# - [generate_commit648_many_body_diagnostics_figures.py](../examples/python/ch61/generate_commit648_many_body_diagnostics_figures.py)
# - [generate_commit649_topological_superconductivity_figures.py](../examples/python/ch61/generate_commit649_topological_superconductivity_figures.py)
# - [generate_commit650_tensor_network_figures.py](../examples/python/ch61/generate_commit650_tensor_network_figures.py)
# - [generate_commit651_thermal_nonequilibrium_figures.py](../examples/python/ch61/generate_commit651_thermal_nonequilibrium_figures.py)
# - [many_body_diagnostics.py](../examples/python/ch61/many_body_diagnostics.py)
# - [many_body_launch.py](../examples/python/ch61/many_body_launch.py)
# - [tensor_network_diagnostics.py](../examples/python/ch61/tensor_network_diagnostics.py)
# - [thermal_nonequilibrium.py](../examples/python/ch61/thermal_nonequilibrium.py)
# - [topological_superconductivity.py](../examples/python/ch61/topological_superconductivity.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch61").is_dir())
chapter_dir = theory_root / "examples/python/ch61"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'bcs_mean_field.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
