# %% [markdown]
# # Theory · Chapter 59
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch59)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [ch59_commit636_coupled_effective.py](../examples/python/ch59/ch59_commit636_coupled_effective.py)
# - [ch59_commit637_two_qubit_gates.py](../examples/python/ch59/ch59_commit637_two_qubit_gates.py)
# - [ch59_commit638_effective_engineering.py](../examples/python/ch59/ch59_commit638_effective_engineering.py)
# - [ch59_commit639_networks_prefreeze.py](../examples/python/ch59/ch59_commit639_networks_prefreeze.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch59").is_dir())
chapter_dir = theory_root / "examples/python/ch59"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'ch59_commit636_coupled_effective.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
