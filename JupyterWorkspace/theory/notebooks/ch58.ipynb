# %% [markdown]
# # Theory · Chapter 58
#
# [All chapters](../INDEX.ipynb) · [Source folder](../examples/python/ch58)
#
# Run the setup cell, choose a script, then run the last cell. Figure generators save output under `theory/generated/`.
#
# ## Scripts
#
# - [ch58_commit632_dynamics.py](../examples/python/ch58/ch58_commit632_dynamics.py)
# - [ch58_commit633_control.py](../examples/python/ch58/ch58_commit633_control.py)
# - [ch58_commit634_optimal_control.py](../examples/python/ch58/ch58_commit634_optimal_control.py)
# - [ch58_commit635_calibration_validation.py](../examples/python/ch58/ch58_commit635_calibration_validation.py)
# - [two_level_launch.py](../examples/python/ch58/two_level_launch.py)

# %%
from pathlib import Path
import os
import sys

theory_root = next(p for p in (Path.cwd(), *Path.cwd().parents) if (p / "examples/python/ch58").is_dir())
chapter_dir = theory_root / "examples/python/ch58"
os.chdir(theory_root)
if str(chapter_dir) not in sys.path:
    sys.path.insert(0, str(chapter_dir))
print("Chapter directory:", chapter_dir)

# %%
script_name = 'ch58_commit632_dynamics.py'
script_path = chapter_dir / script_name
print(script_path)

# %%
get_ipython().run_line_magic("run", f'"{script_path}"')
